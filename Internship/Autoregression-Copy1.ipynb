# %%
import pandas as pd
from pandas import ExcelWriter
from pandas import ExcelFile
#import geopandas as gpd
from shapely.geometry import Point
import shapely
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats
import statsmodels.tsa.stattools as sm
from statsmodels.tsa.arima_model import ARMA
from statsmodels.tsa.arima_model import ARIMA
from statsmodels.tsa.ar_model import AR
# Out:
# /Users/VarshiniSelvadurai/anaconda3/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /Users/VarshiniSelvadurai/anaconda3/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /Users/VarshiniSelvadurai/anaconda3/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /Users/VarshiniSelvadurai/anaconda3/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)

# %%
data = pd.read_excel('/Users/VarshiniSelvadurai/Documents/Internship/Crime_Edited.xlsx', sheet_name = '2017')
#data = pd.read_excel('C:\\Users\\vns8\\Documents\\Crime_Edited.xlsx', sheet_name = '2017')
data = data.loc[data["Crime Name1"] != "Not a Crime"]
data = data.drop(columns = ["Police District Number","Address Number","Victims","CR Number","NIBRS Code","Beat","PRA","State","Incident ID","Offence Code","Sector","Police District Name","Crime Name2","Crime Name3","Agency","Place","End Date/Time","Dispatch Date/Time","Block_Address"])
ugh = list(map(str, data["Start Time"]))
for i in range (0, len(ugh)):
    ugh[i] = ugh[i][:2]
data["Start Time"] = ugh
ugh = (list(map(str,data['Start Date'])))
ughh = []
for i in range(0,len(ugh)):
    ugh[i] = ugh[i][5:]
    ugh[i] = ugh[i][:5]
data['Start Date'] = ugh

# %%
data_2018 = pd.read_excel('/Users/VarshiniSelvadurai/Documents/Internship/Crime_Edited.xlsx', sheet_name = '2018')
#data_2018 = pd.read_excel('C:\\Users\\vns8\\Documents\\Crime_Edited.xlsx', sheet_name = '2018')
data_2018 = data_2018.loc[data_2018["Crime Name1"] != "Not a Crime"]
data_2018 = data_2018.drop(columns = ["Police District Number","Address Number","Victims","CR Number","NIBRS Code","Beat","PRA","State","Incident ID","Offence Code","Sector","Police District Name","Crime Name2","Crime Name3","Agency","Place","End Date/Time","Dispatch Date/Time","Block_Address"])
ugh = list(map(str, data_2018["Start Time"]))
for i in range (0, len(ugh)):
    ugh[i] = ugh[i][:2]
data_2018["Start Time"] = ugh
ugh = (list(map(str,data_2018['Start Date'])))
ughh = []
for i in range(0,len(ugh)):
    ugh[i] = ugh[i][5:]
    ugh[i] = ugh[i][:5]
data_2018['Start Date'] = ugh

# %%
z_20902 = data.loc[data["Zip Code"] == 20902]
z_20906 = data.loc[data["Zip Code"] == 20906]
z_20904 = data.loc[data["Zip Code"] == 20904]
z_20910 = data.loc[data["Zip Code"] == 20910]
z_20874 = data.loc[data["Zip Code"] == 20874]
z_20902_2018 = data_2018.loc[data_2018["Zip Code"] == 20902]
z_20906_2018 = data_2018.loc[data_2018["Zip Code"] == 20906]
z_20904_2018 = data_2018.loc[data_2018["Zip Code"] == 20904]
z_20910_2018 = data_2018.loc[data_2018["Zip Code"] == 20910]
z_20874_2018 = data_2018.loc[data_2018["Zip Code"] == 20874]

# %%
from dateutil import rrule, parser
def daycount(data):
    start_date = list(map(str, data['Start Date'].value_counts().keys().tolist()))
    if (len(start_date)!=365):
        start_date.append("04-23")
    start_date.sort()
    ugh = [0 for i in range(0,len(start_date))]
    for index,row in data.iterrows():
        a = start_date.index(row["Start Date"])
        ugh[a] += 1.0
    start_date = list(rrule.rrule(rrule.DAILY,
                         dtstart=parser.parse("2017-01-01"),
                         until=parser.parse("2017-12-31")))
    for i in range (0,len(start_date)):
        start_date[i] =start_date[i].date()
    march = pd.DataFrame({"Crime Count": ugh, "Date":start_date} )
    #ax = march.plot(kind = "line", y = "Crime Count", figsize = (40,10), title = ("2017" +str(title)), xticks = [0,31,59,90,120,151,181,212,243,273,304,334,365], grid = True)
    #fig = ax.get_figure()
    #fig.savefig("2017" + title + ".png")
    return march

# %%
def daycount_2018(data):
    start_date = ['01-01', '01-02', '01-03', '01-04', '01-05', '01-06', '01-07', '01-08', '01-09', '01-10', '01-11', '01-12', '01-13', '01-14', '01-15', '01-16', '01-17', '01-18', '01-19', '01-20', '01-21', '01-22', '01-23', '01-24', '01-25', '01-26', '01-27', '01-28', '01-29', '01-30', '01-31', '02-01', '02-02', '02-03', '02-04', '02-05', '02-06', '02-07', '02-08', '02-09', '02-10', '02-11', '02-12', '02-13', '02-14', '02-15', '02-16', '02-17', '02-18', '02-19', '02-20', '02-21', '02-22', '02-23', '02-24', '02-25', '02-26', '02-27', '02-28', '03-01', '03-02', '03-03', '03-04', '03-05', '03-06', '03-07', '03-08', '03-09', '03-10', '03-11', '03-12', '03-13', '03-14', '03-15', '03-16', '03-17', '03-18', '03-19', '03-20', '03-21', '03-22', '03-23', '03-24', '03-25', '03-26', '03-27', '03-28', '03-29', '03-30', '03-31', '04-01', '04-02', '04-03', '04-04', '04-05', '04-06', '04-07', '04-08', '04-09', '04-10', '04-11', '04-12', '04-13', '04-14', '04-15', '04-16', '04-17', '04-18', '04-19', '04-20', '04-21', '04-22', '04-23', '04-24', '04-25', '04-26', '04-27', '04-28', '04-29', '04-30', '05-01', '05-02', '05-03', '05-04', '05-05', '05-06', '05-07', '05-08', '05-09', '05-10', '05-11', '05-12', '05-13', '05-14', '05-15', '05-16', '05-17', '05-18', '05-19', '05-20', '05-21', '05-22', '05-23', '05-24', '05-25', '05-26', '05-27', '05-28', '05-29', '05-30', '05-31', '06-01', '06-02', '06-03', '06-04', '06-05', '06-06', '06-07', '06-08', '06-09', '06-10', '06-11', '06-12', '06-13', '06-14', '06-15', '06-16', '06-17', '06-18', '06-19', '06-20']
    ugh = [0 for i in range(0,len(start_date))]
    for index,row in data.iterrows():
        a = start_date.index(row["Start Date"])
        ugh[a] += 1.0
    start_date = list(rrule.rrule(rrule.DAILY,
                         dtstart=parser.parse("2018-01-01"),
                         until=parser.parse("2018-06-20")))
    for i in range (0,len(start_date)):
        start_date[i] =start_date[i].date()
    march = pd.DataFrame({"Crime Count": ugh, "Date":start_date} )
    #ax = march.plot(kind = "line", y = "Crime Count", figsize = (40,10), title = ("2017" +str(title)), xticks = [0,31,59,90,120,151,181,212,243,273,304,334,365], grid = True)
    #fig = ax.get_figure()
    #fig.savefig("2017" + title + ".png")
    return march

# %%
day_20902 = daycount(z_20902)
day_20906 = daycount(z_20906)
day_20904 = daycount(z_20904)
day_20910 = daycount(z_20910)
day_20874 = daycount(z_20874)
day_20902_2018 = daycount_2018(z_20902_2018)
day_20906_2018 = daycount_2018(z_20906_2018)
day_20904_2018 = daycount_2018(z_20904_2018)
day_20910_2018 = daycount_2018(z_20910_2018)
day_20874_2018 = daycount_2018(z_20874_2018)

# %%
zipcode = [day_20906,day_20904,day_20910,day_20874,day_20902]
zipcode_2018 = [day_20906_2018,day_20904_2018,day_20910_2018,day_20874_2018,day_20902_2018]
zipcode_name = [20906,20904,20910,20874,20902]
for i in range (0,5):
    #day_20902_2018.plot()
    print(zipcode_name[i])
    mod = AR(zipcode[i]["Crime Count"])
    print(mod.select_order(ic = "aic",maxlag = 7))
    res = mod.fit(ic = 'aic',maxlag = 7)
    #res.plot_predict(start=365, end=535)
    #plt.show()
    #print(res.summary())
    y = res.predict(start=365, end=535).tolist()
    y_hat = zipcode_2018[i]["Crime Count"].tolist()
    resid = []
    for r in range (0,len(y_hat)):
        resid.append((y_hat[r] - y[r]) * (y_hat[r] - y[r]))
    print("MSE:",np.mean(resid))
    #plt.figure(figsize=(10,5))
    #plt.plot(y_hat)
    #plt.plot(y)
    #plt.show()
# Out:
# 20906
# 7
# MSE: 12.401407258520976
# 20904
# 1
# MSE: 17.540601329487693
# 20910
# 1
# MSE: 21.307992941106182
# 20874
# 7
# MSE: 16.908680395074875
# 20902
# 1
# MSE: 20.816689838049157

# %% [markdown]
# 20906
# 7
# MSE: 12.401407258520976
# 20904
# 1
# MSE: 17.540601329487693
# 20910
# 1
# MSE: 21.307992941106182
# 20874
# 7
# MSE: 16.908680395074875
# 20902
# 1
# MSE: 20.816689838049157

# %%
zipcode = [day_20906,day_20904,day_20910,day_20874,day_20902]
zipcode_2018 = [day_20906_2018,day_20904_2018,day_20910_2018,day_20874_2018,day_20902_2018]
zipcode_name = [20906,20904,20910,20874,20902]
zipcode_order = [(7,7),(4,4),(4,4),(3,3),(5,4)]
for i in range (0,5):
    #day_20902_2018.plot()
    print(zipcode_name[i])
    mod = ARMA(zipcode[i]["Crime Count"],order = zipcode_order[i])
    print("(p,q):", zipcode_order[i])
    res = mod.fit()
    print("2018")
    y = res.predict(start=365, end=535).tolist()
    y_hat = zipcode_2018[i]["Crime Count"].tolist()
    resid = []
    for r in range (0,len(y_hat)):
        resid.append((y_hat[r] - y[r]) * (y_hat[r] - y[r]))
    print("MSE:",np.mean(resid))
    #plt.figure(figsize=(10,5))
    #plt.plot(y_hat)
    #plt.plot(y)
    #plt.show()
    
    print("2017")
    y_2017 = res.predict(start=0, end=365).tolist()
    y_hat_2017 = zipcode[i]["Crime Count"].tolist()
    resid_2017 = []
    for r in range (0,len(y_hat_2017)):
        resid_2017.append((y_hat_2017[r] - y_2017[r]) * (y_hat_2017[r] - y_2017[r]))
    print("MSE:",np.mean(resid_2017))    
    print()
    #plt.figure(figsize=(10,5))
    #plt.plot(y_hat_2017)
    #plt.plot(y_2017)
    #plt.show()
# Out:
# 20906
# (p,q): (7, 7)
# /Users/VarshiniSelvadurai/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:508: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# 2018
# MSE: 12.269654279677876
# 2017
# MSE: 10.84733131465459
#
# 20904
# (p,q): (4, 4)
# /Users/VarshiniSelvadurai/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:488: HessianInversionWarning: Inverting hessian failed, no bse or cov_params available
#   'available', HessianInversionWarning)
# 2018
# MSE: 17.494428894296437
# 2017
# MSE: 12.9255576311256
#
# 20910
# (p,q): (4, 4)
# 2018
# MSE: 22.356365757651478
# 2017
# MSE: 21.81634299338396
#
# 20874
# (p,q): (3, 3)
# 2018
# MSE: 17.16652529616319
# 2017
# MSE: 13.365355595063075
#
# 20902
# (p,q): (5, 4)
# 2018
# MSE: 20.56271076138992
# 2017
# MSE: 15.325649124236252

# %% [markdown]
#     ugh = []
#     ughh = []
#     for p in range (0,8):
#         for q in range(0,8):
#             try:
#                 mod = ARMA(zipcode[i]["Crime Count"],order = (p,q))
#                 res = mod.fit()
#                 #print(p,q)
#                 #print(res.aic)
#                 ugh.append((p,q))
#                 ughh.append(res.aic)
#             except:
#                 continue
# 20906
# (p,q): (7, 7)
# AIC: 1937.5631607906917
# 2018
# MSE: 12.269654279677876
# 2017
# MSE: 10.84733131465459
#
# 20904
# (p,q): (4, 4)
# AIC: 1990.6758267523574
# 2018
# MSE: 17.494428894296437
# 2017
# MSE: 12.9255576311256
#
# 20910
# (p,q): (4, 4)
# AIC: 2181.4262537259756
# 2018
# MSE: 22.356365757651478
# 2017
# MSE: 21.81634299338396
#
# 20874
# (p,q): (3, 3)
# AIC: 1998.2222023860309
# 2018
# MSE: 17.16652529616319
# 2017
# MSE: 13.365355595063075
#
# 20902
# (p,q): (5, 4)
# AIC: 2054.2187837960632
# 2018
# MSE: 20.56271076138992
# 2017
# MSE: 15.325649124236252
#
# [(7,7),(4,4),(4,4),(3,3),(5,4)]

# %%
zipcode = [day_20906,day_20904,day_20910,day_20874,day_20902]
zipcode_2018 = [day_20906_2018,day_20904_2018,day_20910_2018,day_20874_2018,day_20902_2018]
zipcode_name = [20906,20904,20910,20874,20902]
zipcode_order = [(7,0,7),(4,0,4),(4,0,4),(3,0,3),(5,0,4)]
for i in range (0,5):
    #day_20902_2018.plot()
    print(zipcode_name[i])
    mod = ARIMA(zipcode[i]["Crime Count"],order = zipcode_order[i])
    print("(p,q):", zipcode_order[i])
    res = mod.fit()
    print("2018")
    y = res.predict(start=365, end=535).tolist()
    y_hat = zipcode_2018[i]["Crime Count"].tolist()
    resid = []
    for r in range (0,len(y_hat)):
        resid.append((y_hat[r] - y[r]) * (y_hat[r] - y[r]))
    print("MSE:",np.mean(resid))
    #plt.figure(figsize=(10,5))
    #plt.plot(y_hat)
    #plt.plot(y)
    #plt.show()

# %% [markdown]
# zip_order = [(7,0,7),(4,0,4),(4,0,4),(3,0,3),(5,1,6)]
# 20906
# (p,q): (7, 0, 7)
# 2018
# MSE: 12.269654279677876
# 2017
# MSE: 10.84733131465459
#
# 20904
# (p,q): (4, 0, 4)
# 2018
# MSE: 17.494428894296437
# 2017
# MSE: 12.9255576311256
#
# 20910
# (p,q): (4, 0, 4)
# 2018
# MSE: 22.356365757651478
# 2017
# MSE: 21.81634299338396
#
# 20874
# (p,q): (3, 0, 3)
# 2018
# MSE: 17.16652529616319
# 2017
# MSE: 13.365355595063075
#
# 20902
# (p,q): (5, 1, 6)
# 2018
# MSE: 145.0114257311892
# 2017

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAX
zipcode = [day_20906,day_20904,day_20910,day_20874,day_20902]
zipcode_2018 = [day_20906_2018,day_20904_2018,day_20910_2018,day_20874_2018,day_20902_2018]
zipcode_name = [20906,20904,20910,20874,20902]
for i in range (0,5):
    #day_20902_2018.plot()
    print(zipcode_name[i])
    ugh = []
    ughh = []
    ughhh = []
    for p in range (1,8):
        for d in range (0,8):
            for q in range (0,8):
                for P in range (0,8):
                    for D in range (0,8):
                        for Q in range (0,8):
                            mod = SARIMAX(zipcode[i]["Crime Count"],order=(p,d,q), seasonal_order=(p,d,q,52))
                            res = mod.fit()
                            ugh.append((p,d,q))
                            ughh.append((P,D,Q,52))
                            ughhh.append(res.aic)
    mod = ARIMA(zipcode[i]["Crime Count"],order = ugh[ughhh.index(min(ughhhh))], seasonal_order = ugh[ughhh.index(min(ughhh))])
    print("(p,d,q):",ugh[ughhh.index(min(ughhhh))])
    print("(P,D,Q,52):",ughh[ughhh.index(min(ughhhh))])
    res = mod.fit()
    print("2018")
    y = res.predict(start=365, end=535).tolist()
    y_hat = zipcode_2018[i]["Crime Count"].tolist()
    resid = []
    for r in range (0,len(y_hat)):
        resid.append((y_hat[r] - y[r]) * (y_hat[r] - y[r]))
    print("MSE:",np.mean(resid))
    #plt.figure(figsize=(10,5))
    #plt.plot(y_hat)
    #plt.plot(y)
    #plt.show()
# Out:
# 20906

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAX
import warnings
import itertools
y = day_20906["Crime Count"]
p = d = q = range(0, 8)
# Generate all different combinations of p, q and q triplets
pdq = list(itertools.product(p, d, q))
# Generate all different combinations of seasonal p, q and q triplets
seasonal_pdq = [(x[0], x[1], x[2], 52) for x in list(itertools.product(p, d, q))]
warnings.filterwarnings("ignore") # specify to ignore warning messages
ugh = []
ughh = []
ughhh = []
for param in pdq:
    for param_seasonal in seasonal_pdq:
        try:
            mod = SARIMAX(y,
                            order=param,
                            seasonal_order=param_seasonal,
                            enforce_stationarity=False,
                            enforce_invertibility=False)

            results = mod.fit()
            ugh.append(param)
            ughh.append(param_seasonal)
            ughhh.append(results.aic)
            print('ARIMA{}x{}12 - AIC:{}'.format(param, param_seasonal, results.aic))
        except:
            print('ARIMA{}x{}12 - AIC:NOPEEEEEEEE'.format(param, param_seasonal))
print(ugh[ughhh.index(min(ughhh))])
print(ughh[ughhh.index(min(ughhh))])
# Out:
# ARIMA(0, 0, 0)x(0, 0, 0, 52)12 - AIC:2720.1011798296317
# ARIMA(0, 0, 0)x(0, 0, 1, 52)12 - AIC:2132.413001087475
# ARIMA(0, 0, 0)x(0, 0, 2, 52)12 - AIC:11900.112298434971
# ARIMA(0, 0, 0)x(0, 0, 3, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(0, 0, 4, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(0, 0, 5, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(0, 0, 6, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(0, 0, 7, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(0, 1, 0, 52)12 - AIC:1854.7185026003435
# ARIMA(0, 0, 0)x(0, 1, 1, 52)12 - AIC:1459.6459764693705
# ARIMA(0, 0, 0)x(0, 1, 2, 52)12 - AIC:nan
# ARIMA(0, 0, 0)x(0, 1, 3, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(0, 1, 4, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(0, 1, 5, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(0, 1, 6, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(0, 1, 7, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(0, 2, 0, 52)12 - AIC:1805.541680499268
# ARIMA(0, 0, 0)x(0, 2, 1, 52)12 - AIC:1313.2314565327074
# ARIMA(0, 0, 0)x(0, 2, 2, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(0, 2, 3, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(0, 2, 4, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(0, 2, 5, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(0, 2, 6, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(0, 2, 7, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(0, 3, 0, 52)12 - AIC:1616.5941656743885
# ARIMA(0, 0, 0)x(0, 3, 1, 52)12 - AIC:1197.893234943488
# ARIMA(0, 0, 0)x(0, 3, 2, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(0, 3, 3, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(0, 3, 4, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(0, 3, 5, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(0, 3, 6, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(0, 3, 7, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(0, 4, 0, 52)12 - AIC:1349.9070675657658
# ARIMA(0, 0, 0)x(0, 4, 1, 52)12 - AIC:nan
# ARIMA(0, 0, 0)x(0, 4, 2, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(0, 4, 3, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(0, 4, 4, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(0, 4, 5, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(0, 4, 6, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(0, 4, 7, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(0, 5, 0, 52)12 - AIC:1039.471603673159
# ARIMA(0, 0, 0)x(0, 5, 1, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(0, 5, 2, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(0, 5, 3, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(0, 5, 4, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(0, 5, 5, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(0, 5, 6, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(0, 5, 7, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(0, 6, 0, 52)12 - AIC:613.4292802452103
# ARIMA(0, 0, 0)x(0, 6, 1, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(0, 6, 2, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(0, 6, 3, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(0, 6, 4, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(0, 6, 5, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(0, 6, 6, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(0, 6, 7, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(0, 7, 0, 52)12 - AIC:2.0
# ARIMA(0, 0, 0)x(0, 7, 1, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(0, 7, 2, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(0, 7, 3, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(0, 7, 4, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(0, 7, 5, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(0, 7, 6, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(0, 7, 7, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(1, 0, 0, 52)12 - AIC:1844.9309063707906
# ARIMA(0, 0, 0)x(1, 0, 1, 52)12 - AIC:1767.614401004462
# ARIMA(0, 0, 0)x(1, 0, 2, 52)12 - AIC:8252.185525001894
# ARIMA(0, 0, 0)x(1, 0, 3, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(1, 0, 4, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(1, 0, 5, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(1, 0, 6, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(1, 0, 7, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(1, 1, 0, 52)12 - AIC:1507.1902637494663
# ARIMA(0, 0, 0)x(1, 1, 1, 52)12 - AIC:1480.5077763647168
# ARIMA(0, 0, 0)x(1, 1, 2, 52)12 - AIC:nan
# ARIMA(0, 0, 0)x(1, 1, 3, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(1, 1, 4, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(1, 1, 5, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(1, 1, 6, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(1, 1, 7, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(1, 2, 0, 52)12 - AIC:1367.4063967242682
# ARIMA(0, 0, 0)x(1, 2, 1, 52)12 - AIC:1319.0601033829632
# ARIMA(0, 0, 0)x(1, 2, 2, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(1, 2, 3, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(1, 2, 4, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(1, 2, 5, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(1, 2, 6, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(1, 2, 7, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(1, 3, 0, 52)12 - AIC:1132.8659333104524
# ARIMA(0, 0, 0)x(1, 3, 1, 52)12 - AIC:1127.4097720431669
# ARIMA(0, 0, 0)x(1, 3, 2, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(1, 3, 3, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(1, 3, 4, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(1, 3, 5, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(1, 3, 6, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(1, 3, 7, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(1, 4, 0, 52)12 - AIC:884.5838182775208
# ARIMA(0, 0, 0)x(1, 4, 1, 52)12 - AIC:nan
# ARIMA(0, 0, 0)x(1, 4, 2, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(1, 4, 3, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(1, 4, 4, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(1, 4, 5, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(1, 4, 6, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(1, 4, 7, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(1, 5, 0, 52)12 - AIC:498.82085290478864
# ARIMA(0, 0, 0)x(1, 5, 1, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(1, 5, 2, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(1, 5, 3, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(1, 5, 4, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(1, 5, 5, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(1, 5, 6, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(1, 5, 7, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(1, 6, 0, 52)12 - AIC:nan
# ARIMA(0, 0, 0)x(1, 6, 1, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(1, 6, 2, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(1, 6, 3, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(1, 6, 4, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(1, 6, 5, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(1, 6, 6, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(1, 6, 7, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(1, 7, 0, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(1, 7, 1, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(1, 7, 2, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(1, 7, 3, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(1, 7, 4, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(1, 7, 5, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(1, 7, 6, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(1, 7, 7, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(2, 0, 0, 52)12 - AIC:1504.168564041287
# ARIMA(0, 0, 0)x(2, 0, 1, 52)12 - AIC:1487.4331337970336
# ARIMA(0, 0, 0)x(2, 0, 2, 52)12 - AIC:8753.541148563363
# ARIMA(0, 0, 0)x(2, 0, 3, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(2, 0, 4, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(2, 0, 5, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(2, 0, 6, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(2, 0, 7, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(2, 1, 0, 52)12 - AIC:1185.14007506344
# ARIMA(0, 0, 0)x(2, 1, 1, 52)12 - AIC:1182.6632668554107
# ARIMA(0, 0, 0)x(2, 1, 2, 52)12 - AIC:nan
# ARIMA(0, 0, 0)x(2, 1, 3, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(2, 1, 4, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(2, 1, 5, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(2, 1, 6, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(2, 1, 7, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(2, 2, 0, 52)12 - AIC:993.3865518382843
# ARIMA(0, 0, 0)x(2, 2, 1, 52)12 - AIC:984.2717236825546
# ARIMA(0, 0, 0)x(2, 2, 2, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(2, 2, 3, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(2, 2, 4, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(2, 2, 5, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(2, 2, 6, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(2, 2, 7, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(2, 3, 0, 52)12 - AIC:747.9872454889296
# ARIMA(0, 0, 0)x(2, 3, 1, 52)12 - AIC:749.8924154935961
# ARIMA(0, 0, 0)x(2, 3, 2, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(2, 3, 3, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(2, 3, 4, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(2, 3, 5, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(2, 3, 6, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(2, 3, 7, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(2, 4, 0, 52)12 - AIC:433.85668554987313
# ARIMA(0, 0, 0)x(2, 4, 1, 52)12 - AIC:nan
# ARIMA(0, 0, 0)x(2, 4, 2, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(2, 4, 3, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(2, 4, 4, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(2, 4, 5, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(2, 4, 6, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(2, 4, 7, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(2, 5, 0, 52)12 - AIC:nan
# ARIMA(0, 0, 0)x(2, 5, 1, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(2, 5, 2, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(2, 5, 3, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(2, 5, 4, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(2, 5, 5, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(2, 5, 6, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(2, 5, 7, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(2, 6, 0, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(2, 6, 1, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(2, 6, 2, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(2, 6, 3, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(2, 6, 4, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(2, 6, 5, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(2, 6, 6, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(2, 6, 7, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(2, 7, 0, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(2, 7, 1, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(2, 7, 2, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(2, 7, 3, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(2, 7, 4, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(2, 7, 5, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(2, 7, 6, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(2, 7, 7, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(3, 0, 0, 52)12 - AIC:1186.8016564690506
# ARIMA(0, 0, 0)x(3, 0, 1, 52)12 - AIC:1184.6653677663933
# ARIMA(0, 0, 0)x(3, 0, 2, 52)12 - AIC:7145.129155594303
# ARIMA(0, 0, 0)x(3, 0, 3, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(3, 0, 4, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(3, 0, 5, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(3, 0, 6, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(3, 0, 7, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(3, 1, 0, 52)12 - AIC:895.2299972258534
# ARIMA(0, 0, 0)x(3, 1, 1, 52)12 - AIC:895.8195750354264
# ARIMA(0, 0, 0)x(3, 1, 2, 52)12 - AIC:nan
# ARIMA(0, 0, 0)x(3, 1, 3, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(3, 1, 4, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(3, 1, 5, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(3, 1, 6, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(3, 1, 7, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(3, 2, 0, 52)12 - AIC:668.0560647238149
# ARIMA(0, 0, 0)x(3, 2, 1, 52)12 - AIC:664.2713302404126
# ARIMA(0, 0, 0)x(3, 2, 2, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(3, 2, 3, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(3, 2, 4, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(3, 2, 5, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(3, 2, 6, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(3, 2, 7, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(3, 3, 0, 52)12 - AIC:384.31705855001695
# ARIMA(0, 0, 0)x(3, 3, 1, 52)12 - AIC:386.15221886881415
# ARIMA(0, 0, 0)x(3, 3, 2, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(3, 3, 3, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(3, 3, 4, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(3, 3, 5, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(3, 3, 6, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(3, 3, 7, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(3, 4, 0, 52)12 - AIC:nan
# ARIMA(0, 0, 0)x(3, 4, 1, 52)12 - AIC:nan
# ARIMA(0, 0, 0)x(3, 4, 2, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(3, 4, 3, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(3, 4, 4, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(3, 4, 5, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(3, 4, 6, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(3, 4, 7, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(3, 5, 0, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(3, 5, 1, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(3, 5, 2, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(3, 5, 3, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(3, 5, 4, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(3, 5, 5, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(3, 5, 6, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(3, 5, 7, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(3, 6, 0, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(3, 6, 1, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(3, 6, 2, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(3, 6, 3, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(3, 6, 4, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(3, 6, 5, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(3, 6, 6, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(3, 6, 7, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(3, 7, 0, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(3, 7, 1, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(3, 7, 2, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(3, 7, 3, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(3, 7, 4, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(3, 7, 5, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(3, 7, 6, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(3, 7, 7, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(4, 0, 0, 52)12 - AIC:897.2127518410363
# ARIMA(0, 0, 0)x(4, 0, 1, 52)12 - AIC:897.7220208676554
# ARIMA(0, 0, 0)x(4, 0, 2, 52)12 - AIC:898.344070215869
# ARIMA(0, 0, 0)x(4, 0, 3, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(4, 0, 4, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(4, 0, 5, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(4, 0, 6, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(4, 0, 7, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(4, 1, 0, 52)12 - AIC:606.8786713479942
# ARIMA(0, 0, 0)x(4, 1, 1, 52)12 - AIC:608.8624012713091
# ARIMA(0, 0, 0)x(4, 1, 2, 52)12 - AIC:nan
# ARIMA(0, 0, 0)x(4, 1, 3, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(4, 1, 4, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(4, 1, 5, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(4, 1, 6, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(4, 1, 7, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(4, 2, 0, 52)12 - AIC:322.264099622629
# ARIMA(0, 0, 0)x(4, 2, 1, 52)12 - AIC:324.1502397310252
# ARIMA(0, 0, 0)x(4, 2, 2, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(4, 2, 3, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(4, 2, 4, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(4, 2, 5, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(4, 2, 6, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(4, 2, 7, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(4, 3, 0, 52)12 - AIC:-9.832934253687174
# ARIMA(0, 0, 0)x(4, 3, 1, 52)12 - AIC:nan
# ARIMA(0, 0, 0)x(4, 3, 2, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(4, 3, 3, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(4, 3, 4, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(4, 3, 5, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(4, 3, 6, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(4, 3, 7, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(4, 4, 0, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(4, 4, 1, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(4, 4, 2, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(4, 4, 3, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(4, 4, 4, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(4, 4, 5, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(4, 4, 6, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(4, 4, 7, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(4, 5, 0, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(4, 5, 1, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(4, 5, 2, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(4, 5, 3, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(4, 5, 4, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(4, 5, 5, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(4, 5, 6, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(4, 5, 7, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(4, 6, 0, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(4, 6, 1, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(4, 6, 2, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(4, 6, 3, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(4, 6, 4, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(4, 6, 5, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(4, 6, 6, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(4, 6, 7, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(4, 7, 0, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(4, 7, 1, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(4, 7, 2, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(4, 7, 3, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(4, 7, 4, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(4, 7, 5, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(4, 7, 6, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(4, 7, 7, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(5, 0, 0, 52)12 - AIC:608.6027029299141
# ARIMA(0, 0, 0)x(5, 0, 1, 52)12 - AIC:610.5888118522673
# ARIMA(0, 0, 0)x(5, 0, 2, 52)12 - AIC:612.3155478679381
# ARIMA(0, 0, 0)x(5, 0, 3, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(5, 0, 4, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(5, 0, 5, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(5, 0, 6, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(5, 0, 7, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(5, 1, 0, 52)12 - AIC:308.5551359439716
# ARIMA(0, 0, 0)x(5, 1, 1, 52)12 - AIC:310.2004887113774
# ARIMA(0, 0, 0)x(5, 1, 2, 52)12 - AIC:nan
# ARIMA(0, 0, 0)x(5, 1, 3, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(5, 1, 4, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(5, 1, 5, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(5, 1, 6, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(5, 1, 7, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(5, 2, 0, 52)12 - AIC:-9.976903647532065
# ARIMA(0, 0, 0)x(5, 2, 1, 52)12 - AIC:nan
# ARIMA(0, 0, 0)x(5, 2, 2, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(5, 2, 3, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 0)x(5,
 1, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 1)x(0, 5, 2, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 1)x(0, 5, 3, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 1)x(0, 5, 4, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 1)x(0, 5, 5, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 1)x(0, 5, 6, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 1)x(0, 5, 7, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 1)x(0, 6, 0, 52)12 - AIC:597.3906032743041
# ARIMA(0, 0, 1)x(0, 6, 1, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 1)x(0, 6, 2, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 1)x(0, 6, 3, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 1)x(0, 6, 4, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 1)x(0, 6, 5, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 1)x(0, 6, 6, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 1)x(0, 6, 7, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 1)x(0, 7, 0, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 1)x(0, 7, 1, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 1)x(0, 7, 2, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 1)x(0, 7, 3, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 1)x(0, 7, 4, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 1)x(0, 7, 5, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 1)x(0, 7, 6, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 1)x(0, 7, 7, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 1)x(1, 0, 0, 52)12 - AIC:1846.9055457480176
# ARIMA(0, 0, 1)x(1, 0, 1, 52)12 - AIC:1762.709473433487
# ARIMA(0, 0, 1)x(1, 0, 2, 52)12 - AIC:10105.221029889715
# ARIMA(0, 0, 1)x(1, 0, 3, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 1)x(1, 0, 4, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 1)x(1, 0, 5, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 1)x(1, 0, 6, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 1)x(1, 0, 7, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 1)x(1, 1, 0, 52)12 - AIC:1509.1902591345597
# ARIMA(0, 0, 1)x(1, 1, 1, 52)12 - AIC:1476.78054843802
# ARIMA(0, 0, 1)x(1, 1, 2, 52)12 - AIC:1170.620073595287
# ARIMA(0, 0, 1)x(1, 1, 3, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 1)x(1, 1, 4, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 1)x(1, 1, 5, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 1)x(1, 1, 6, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 1)x(1, 1, 7, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 1)x(1, 2, 0, 52)12 - AIC:1369.0437290902637
# ARIMA(0, 0, 1)x(1, 2, 1, 52)12 - AIC:1313.4075368354625
# ARIMA(0, 0, 1)x(1, 2, 2, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 1)x(1, 2, 3, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 1)x(1, 2, 4, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 1)x(1, 2, 5, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 1)x(1, 2, 6, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 1)x(1, 2, 7, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 1)x(1, 3, 0, 52)12 - AIC:1134.3524931528445
# ARIMA(0, 0, 1)x(1, 3, 1, 52)12 - AIC:1119.5122173126128
# ARIMA(0, 0, 1)x(1, 3, 2, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 1)x(1, 3, 3, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 1)x(1, 3, 4, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 1)x(1, 3, 5, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 1)x(1, 3, 6, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 1)x(1, 3, 7, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 1)x(1, 4, 0, 52)12 - AIC:885.8183034775826
# ARIMA(0, 0, 1)x(1, 4, 1, 52)12 - AIC:846.0319914343105
# ARIMA(0, 0, 1)x(1, 4, 2, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 1)x(1, 4, 3, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 1)x(1, 4, 4, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 1)x(1, 4, 5, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 1)x(1, 4, 6, 52)12 - AIC:NOPEEEEEEEE
# ARIMA(0, 0, 1)x(1, 4, 7, 52)12 - AIC:NOPEEEEEEEE

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAX
import warnings
import itertools
y = day_20904["Crime Count"]
p = d = q = range(0, 8)
# Generate all different combinations of p, q and q triplets
pdq = list(itertools.product(p, d, q))
# Generate all different combinations of seasonal p, q and q triplets
seasonal_pdq = [(x[0], x[1], x[2], 52) for x in list(itertools.product(p, d, q))]
warnings.filterwarnings("ignore") # specify to ignore warning messages
ugh = []
ughh = []
ughhh = []
for param in pdq:
    for param_seasonal in seasonal_pdq:
        try:
            mod = SARIMAX(y,
                            order=param,
                            seasonal_order=param_seasonal,
                            enforce_stationarity=False,
                            enforce_invertibility=False)

            results = mod.fit()
            ugh.append(param)
            ughh.append(param_seasonal)
            ughhh.append(results.aic)
            print('ARIMA{}x{}12 - AIC:{}'.format(param, param_seasonal, results.aic))
        except:
            print('ARIMA{}x{}12 - AIC:NOPEEEEEEEE'.format(param, param_seasonal))
print(ugh[ughhh.index(min(ughhh))])
print(ughh[ughhh.index(min(ughhh))])

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAX
import warnings
import itertools
y = day_20910["Crime Count"]
p = d = q = range(0, 8)
# Generate all different combinations of p, q and q triplets
pdq = list(itertools.product(p, d, q))
# Generate all different combinations of seasonal p, q and q triplets
seasonal_pdq = [(x[0], x[1], x[2], 52) for x in list(itertools.product(p, d, q))]
warnings.filterwarnings("ignore") # specify to ignore warning messages
ugh = []
ughh = []
ughhh = []
for param in pdq:
    for param_seasonal in seasonal_pdq:
        try:
            mod = SARIMAX(y,
                            order=param,
                            seasonal_order=param_seasonal,
                            enforce_stationarity=False,
                            enforce_invertibility=False)

            results = mod.fit()
            ugh.append(param)
            ughh.append(param_seasonal)
            ughhh.append(results.aic)
            print('ARIMA{}x{}12 - AIC:{}'.format(param, param_seasonal, results.aic))
        except:
